# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 26.2 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 3.2.1
#     Uninstalling keras-3.2.1:
#       Successfully uninstalled keras-3.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# ...

# %%
import tensorflow as tf 
import os
import pandas as pd

# %%
# this is used for making sure that the tensorflow don't take all the gpu vram space
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# %%
len(gpus)
# Out:
# 1

# %%
import cv2
import imghdr

# %%
# h_d=pd.read_csv("/kaggle/input/happy-animal-dataset")
image_ext=['jpeg','jpg','bmp','png']

# %%
 os.listdir(os.path.join("/kaggle/input","happy-animal-dataset"))
# Out:
# ['images133.jpg',
#  'images141.jpg',
#  'images77.jpg',
#  'animals-mos-3_031916012516.jpg',
#  'images68.jpg',
#  'images69.jpg',
#  'images85.jpg',
#  'SEI_162172440.jpg',
#  'images56.jpg',
#  'happy-animal-africa-white-background-illustration-69443309.jpg',
#  'image39.jpeg',
#  'animals-story2C-fb_647_031916013853.jpg',
#  'happy_10.jpeg',
#  'images22.jpg',
#  'image23.jpeg',
#  'BL7UFAtCMAIuwWV.jpg',
#  'images11.jpg',
#  'images127.jpg',
#  'images65.jpg',
#  'tiger-160601_1280.png',
#  '51pUksuDyLL.jpg',
#  'Happy-animals-in-the-forest-cartoon-vector.jpg',
#  'image9.jpeg',
#  'image49.jpeg',
#  'happy-animals-in-the-nature-2GWCG8G.jpg',
#  'images21.jpg',
#  'image21.jpeg',
#  'images131.jpg',
#  'happy_6.jpeg',
#  'image33.jpeg',
#  'image44.jpeg',
#  'petblogbaby.png',
#  'image27.jpeg',
#  'images31.jpg',
#  'images33.jpg',
#  'images45.jpg',
#  'quokkas2Bwell2Bbeings2Bmeraki2Bbranding.jpg',
#  'image18.jpeg',
#  'happy_3.jpeg',
#  'images97.jpg',
# ...

# %%
data_dir="/kaggle/input"
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir,image_class)):
        image_path=os.path.join(data_dir,image_class,image)
        try:
            img=cv2.imread(image_path)
            tip=imghdr.what(image_path)
            if tip not in image_ext:
                print("Image not in ext list {}".format(image_path))
                os.remove(image_path)
        except Exception as e:
            print("Issues with image {}".format(image_path))
#             os.remove(image_path)
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# Image not in ext list /kaggle/input/sad-animal-image-dataset/quokkas2Bwell2Bbeings2Bmeraki2Bbranding.jpg
# Issues with image /kaggle/input/sad-animal-image-dataset/quokkas2Bwell2Bbeings2Bmeraki2Bbranding.jpg
# Image not in ext list /kaggle/input/sad-animal-image-dataset/45798177.jpg
# Issues with image /kaggle/input/sad-animal-image-dataset/45798177.jpg
# Image not in ext list /kaggle/input/sad-animal-image-dataset/46261251.jpg
# Issues with image /kaggle/input/sad-animal-image-dataset/46261251.jpg
# Image not in ext list /kaggle/input/sad-animal-image-dataset/46362881.jpg
# Issues with image /kaggle/input/sad-animal-image-dataset/46362881.jpg
# Image not in ext list /kaggle/input/sad-animal-image-dataset/be0b855f7ca20cf0420f65dd90.jpg
# Issues with image /kaggle/input/sad-animal-image-dataset/be0b855f7ca20cf0420f65dd90.jpg
# ...

# %%
tf.data.Dataset??
# Out:
# Init signature: tf.data.Dataset(variant_tensor)
# Source:
# @tf_export("data.Dataset", v1=[])
# class DatasetV2(
#     collections_abc.Iterable,
#     tracking_base.Trackable,
#     composite_tensor.CompositeTensor,
#     data_types.DatasetV2,
#     metaclass=abc.ABCMeta):
#   """Represents a potentially large set of elements.
#
#   The `tf.data.Dataset` API supports writing descriptive and efficient input
#   pipelines. `Dataset` usage follows a common pattern:
#
#   1. Create a source dataset from your input data.
#   2. Apply dataset transformations to preprocess the data.
#   3. Iterate over the dataset and process the elements.
#
#   Iteration happens in a streaming fashion, so the full dataset does not need to
#   fit into memory.
#
#   Source Datasets:
#
#   The simplest way to create a dataset is to create it from a python `list`:
#
#   >>> dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])
#   >>> for element in dataset:
#   ...   print(element)
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# using the keras utils of tensorflow which will make the images preprosess 
data = tf.keras.utils.image_dataset_from_directory(data_dir)
# Out:
# Found 592 files belonging to 2 classes.

# %%
data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch=data_iterator.next()
len(batch)
# Out:
# 2

# %%
# class 1 = happy animal , class 2 = sad animal
fix , ax = plt.subplots(ncols=4,figsize=(20,20))
for idx ,img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# ##  Preprocess the data

# %%
data = data.map(lambda x, y :(x/255 , y))

# %%
scaled_iterator=data.as_numpy_iterator()

# %%
scaled_iterator.next()[0].max()
# Out:
# 1.0

# %%
train_size=int(len(data)*.7)
val_size=int(len(data)*.2)+1
test_size=int(len(data)*.1)+1

# %%
train=data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# ## Build the deep learning CNN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D, Dense, Flatten,Dropout

# %%
model=Sequential()

# %%
model.add(Conv2D(16,(3,3),1,activation='relu',input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())
 
model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation="sigmoid"))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.compile('adam',loss=tf.losses.BinaryCrossentropy(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 16)     │         4,624 │
# ...

# %% [markdown]
# ## Train the model

# %%
logdir='/kaggle/working/logs'

# %%
tensor_callback=tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
 hist=model.fit(train,epochs=20,validation_data=val,callbacks=[tensor_callback])
# Out:
# Epoch 1/20
# 2024-05-17 18:49:57.652973: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 5.18467, expected 4.50617
# 2024-05-17 18:49:57.653035: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 19: 4.79704, expected 4.11855
# 2024-05-17 18:49:57.653044: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 21: 5.68599, expected 5.00749
# 2024-05-17 18:49:57.653052: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 5.3579, expected 4.67941
# 2024-05-17 18:49:57.653060: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 31: 5.10855, expected 4.43005
# 2024-05-17 18:49:57.653068: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 72: 4.95392, expected 4.27543
# 2024-05-17 18:49:57.653076: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 73: 5.76862, expected 5.09012
# ...

# %%
flt=plt.figure()
plt.plot(hist.history['loss'],color='teal',label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val_loss')
flt.suptitle('loss',fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
flt=plt.figure()
plt.plot(hist.history['accuracy'],color='teal',label='accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='val_accuracy')
flt.suptitle('Accuracy',fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Test for model

# %%
from tensorflow.keras.metrics import Precision , Recall , BinaryAccuracy

# %%
pre=Precision()
re=Recall()
acc=BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    X,y=batch
    yhat=model.predict(X)
    pre.update_state(y,yhat)
    re.update_state(y,yhat)
    acc.update_state(y,yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 2024-05-17 19:02:41.619374: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129032: 6.03902, expected 5.28448
# 2024-05-17 19:02:41.619441: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129033: 5.90904, expected 5.15451
# 2024-05-17 19:02:41.619458: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129039: 5.93969, expected 5.18515
# 2024-05-17 19:02:41.619475: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129040: 5.74327, expected 4.98873
# 2024-05-17 19:02:41.619485: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129051: 5.84169, expected 5.08716
# 2024-05-17 19:02:41.619495: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129052: 5.66065, expected 4.90611
# ...

# %%
print(f'Precision:{pre.result().numpy()} ,Recall: {re.result().numpy()},Accuracy:{acc.result().numpy()}')
# Out:
# Precision:0.30000001192092896 ,Recall: 0.125,Accuracy:0.4166666567325592

# %% [markdown]
# ## Save the model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join("/kaggle/working/models","imageclassifieranimalhappy.h5"))
